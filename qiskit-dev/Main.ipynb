# %% [markdown]
# # Qiskit Demonstration

# %%
# %pip install -q qiskit
# %pip install -q matplotlib
# %pip install -q pylatexenc
# %pip install -q qiskit_aer
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit import *
from qiskit_aer import *

# %%
qc = QuantumCircuit(2)

qc.h(0)

qc.cx(0,1)

qc.draw(output='mpl')

# %%
circ = QuantumCircuit(2, 2)
circ.h(0)
circ.cx(0, 1)
circ.measure([0, 1], [0, 1])
circ.draw(output='mpl')

# %%
backend_sim = Aer.get_backend('qasm_simulator')

# Transpile and assemble the circuit for the backend
t_circ = transpile(circ, backend_sim)
qobj = assemble(t_circ, shots=1024)

job_sim = backend_sim.run(qobj)

result_sim = job_sim.result()

counts = result_sim.get_counts(circ)
print(counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       3 # Transpile and assemble the circuit for the backend
#       4 t_circ = transpile(circ, backend_sim)
# ----> 5 qobj = assemble(t_circ, shots=1024)
#       7 job_sim = backend_sim.run(qobj)
#       9 result_sim = job_sim.result()
#
# NameError: name 'assemble' is not defined
